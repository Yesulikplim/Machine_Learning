# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv('Position_Salaries.csv')

X = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression

lg_model = LinearRegression()

lg_model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures(degree=4)
poly_X = poly_reg.fit_transform(X)
lg_model2 = LinearRegression()
lg_model2.fit(poly_X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X, y)
plt.plot(X, lg_model.predict(X), color='r')
plt.xlabel('Level')
plt.ylabel('Salary')
plt.title("Linear  Regression Prediction")
# Out:
# Text(0.5, 1.0, 'Linear  Regression Prediction')

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X, y)
plt.plot(X, lg_model2.predict(poly_reg.fit_transform(X)), color='r')
plt.xlabel('Level')
plt.ylabel('Salary')
plt.title("Polynomial  Regression Prediction")
# Out:
# Text(0.5, 1.0, 'Polynomial  Regression Prediction')

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), .1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y)
plt.plot(X_grid, lg_model2.predict(poly_reg.fit_transform(X)), color='r')
plt.xlabel('Level')
plt.ylabel('Salary')
plt.title("Polynomial  Regression Prediction")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 4
#       2 X_grid = X_grid.reshape((len(X_grid), 1))
#       3 plt.scatter(X, y)
# ----> 4 plt.plot(X_grid, lg_model2.predict(poly_reg.fit_transform(X)), color='r')
#       5 plt.xlabel('Level')
#       6 plt.ylabel('Salary')
#
# File ~/anaconda3/envs/DS_ML_AI/lib/python3.11/site-packages/matplotlib/pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# ...

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %% [markdown]
# ## Predicting a new result with Polynomial Regression
